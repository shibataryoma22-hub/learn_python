# %% [markdown]
# <a href="https://colab.research.google.com/github/shibataryoma22-hub/learn_python/blob/main/gradient_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def numerical_diff(f, x):
  h = 10e-4
  return f(x + h) - f(x-h) / 2*h #中心差分

# %%
def function_1(x): #xは関数から得られる値を求めるために必要な変数を入力する
  y = 0.01 * x**2 + 0.1*x
  return y

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 20, 0.1)
y = function_1(x)
plt.plot(x, y)
plt.show()

# %%
print(numerical_diff(function_1, 5))
print(numerical_diff(function_1, 10))
# Out:
# 0.7498251099950002
# 1.9993001599950002
